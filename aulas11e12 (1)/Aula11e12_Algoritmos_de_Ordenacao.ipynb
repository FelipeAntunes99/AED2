# %% [markdown]
# ![Algoritmos e Estrutura de Dados II - Prof Piva](AED2_banner.jpg)

# %% [markdown]
# ## Aulas 11 e 12 -  Algoritmos de ordenação

# %% [markdown]
# ![Comparação de Algoritmos de Ordenação](algoritmos.png)

# %% [markdown]
# ## Bubble sort  ( O(n**2) )

# %%
import numpy as np

# %%
def bubble_sort(vetor):
  n = len(vetor)

  for i in range(n):
    for j in range(0, n - i - 1):
      if vetor[j] > vetor[j + 1]:
        vetor[j], vetor[j + 1] = vetor[j+1], vetor[j]
          
  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))
vetor = vet

# %%
# Vetor não ordenado
print(vet)
# Out:
# [146, 324, 38, 46, 493, 689, 39, 38, 635, 855, 73, 232, 237, 675, 628, 883, 18, 41, 564, 121, 488, 88, 198, 776, 667, 370, 142, 828, 328, 605, 157, 200, 100, 273, 119, 30, 558, 235, 124, 779, 230, 3, 562, 932, 502, 995, 599, 135, 892, 696, 218, 246, 46, 688, 612, 596, 718, 294, 227, 502, 349, 647, 179, 905, 451, 435, 267, 12, 905, 323, 50, 119, 731, 236, 364, 924, 566, 926, 243, 759, 557, 427, 31, 228, 519, 340, 587, 151, 919, 257, 5, 181, 571, 499, 281, 698, 771, 144, 104, 885, 208, 998, 778, 880, 960, 42, 927, 139, 339, 123, 689, 217, 930, 679, 657, 724, 956, 7, 238, 196, 791, 552, 289, 105, 852, 478, 779, 856, 662, 949, 667, 255, 393, 59, 784, 68, 934, 570, 59, 712, 881, 139, 612, 36, 488, 222, 539, 468, 290, 908, 2, 814, 474, 612, 699, 661, 750, 646, 513, 614, 551, 301, 415, 291, 544, 459, 319, 885, 690, 880, 195, 173, 673, 138, 315, 509, 572, 409, 982, 461, 621, 208, 687, 293, 855, 578, 223, 369, 119, 250, 615, 555, 917, 254, 702, 949, 158, 168, 217, 530, 863, 612, 33, 815, 964, 574, 985, 311, 587, 907, 515, 462, 276, 673, 34, 521, 608, 223, 388, 452, 331, 736, 694, 256, 801, 643, 268, 578, 325, 755, 703, 267, 47, 695, 985, 300, 361, 493, 2, 251, 12, 736, 8, 825, 138, 794, 558, 347, 198, 904, 664, 926, 189, 572, 864, 797, 40, 54, 273, 696, 184, 347, 791, 263, 734, 42, 704, 869, 894, 66, 767, 163, 187, 858, 996, 1, 153, 546, 361, 719, 451, 77, 644, 464, 477, 144, 729, 3, 619, 674, 267, 736, 127, 739, 720, 430, 872, 587, 800, 657, 883, 419, 199, 111, 318, 799, 211, 545, 284, 53, 154, 227, 445, 852, 928, 992, 827, 613, 942, 531, 48, 679, 811, 110, 295, 979, 347, 937, 627, 154, 921, 126, 517, 320, 199, 1, 508, 195, 388, 684, 797, 949, 658, 454, 610, 936, 848, 83, 375, 787, 667, 241, 766, 775, 297, 494, 212, 393, 57, 373, 781, 529, 624, 110, 409, 681, 872, 346, 725, 116, 294, 191, 884, 980, 346, 673, 827, 226, 254, 281, 106, 769, 865, 59, 349, 812, 170, 197, 901, 608, 812, 153, 669, 83, 658, 
 35, 208, 195, 702, 50, 942, 638, 453, 238, 738, 756, 429, 857, 173, 60, 526, 261, 821, 349, 405, 394, 85, 81, 126, 952, 354, 173, 1, 815, 185, 299, 849, 97, 209, 911, 561, 962, 557, 509, 854, 87, 528, 286, 567, 908, 461, 79, 94, 930, 640, 969, 102, 797, 272, 848, 74, 666, 895, 950, 694, 423, 795, 259, 381, 279, 15, 254, 422, 244, 154, 322, 272, 183, 793, 59, 431, 845, 266, 541, 712, 325, 2, 768, 811, 583, 314, 831, 202, 304, 705, 566, 777, 517, 142, 812, 470, 165, 104, 420, 835, 623, 663, 744, 7, 16, 352, 43, 770, 965, 334, 537, 213, 205, 358, 563, 415, 899, 511, 543, 976, 33, 283, 472, 854, 545, 965, 145, 985, 94, 231, 232, 627, 216, 847, 991, 267, 573, 286, 135, 581, 26, 572, 651, 912, 958, 628, 744, 598, 706, 226, 165, 991, 318, 372, 318, 243, 23, 816, 308, 167, 280, 489, 953, 685, 325, 943, 688, 660, 397, 354, 230, 82, 586, 166, 23, 719, 899, 116, 966, 251, 353, 775, 778, 845, 767, 455, 834, 121, 736, 337, 989, 85, 130, 31, 806, 562, 104, 481, 338, 726, 685, 91, 735, 341, 43, 48, 445, 91, 775, 617, 224, 728, 756, 638, 28, 418, 885, 285, 593, 451, 561, 898, 214, 689, 276, 704, 134, 832, 523, 522, 318, 178, 370, 61, 929, 156, 884, 439, 165, 741, 181, 952, 335, 145, 548, 446, 356, 636, 849, 667, 243, 282, 163, 7 ...

# %% [markdown]
# ## Selection sort    ( O(n**2) )

# %%
def selection_sort(vetor):
  n = len(vetor)

  for i in range(n):
    id_minimo = i
    for j in range(i + 1, n):
      if vetor[id_minimo] > vetor[j]:
        id_minimo = j
    temp = vetor[i]
    vetor[i] = vetor[id_minimo]
    vetor[id_minimo] = temp

  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit selection_sort(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Insertion sort  (  O(n**2) )

# %%
def insertion_sort1(vetor):
    n = len(vetor)
    
    for i in range(1, n):
        marcado = vetor[i]
        
        j = i - 1
        while j >= 0 and marcado < vetor[j]:
            vetor[j + 1] = vetor[j]
            j -= 1
        vetor[j + 1] = marcado
    
    return vetor

# %%
def insertion_sort2(vetor):
    # Percorre cada elemento de L
    for i in range(1, len(vetor)):
        k = i
        # Insere o pivô na posição correta
        while k > 0 and vetor[k] < vetor[k-1]:
            vetor[k], vetor[k-1] = vetor[k-1], vetor[k]
            k = k - 1

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit insertion_sort1(vet)

# %%
# Vetor ordenado
print(vet)

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit insertion_sort2(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Shell sort  (  O(n**2)  - O(n log n) )

# %%
# shell sort
def shell_sort1(vetor):
    n = len(vetor)
    h = 1
    while h > 0:
        for i in range(h, n):
            c = vetor[i]
            j = i
            while j >= h and c < vetor[j - h]:
                vetor[j] = vetor[j - h]
                j = j - h
                vetor[j] = c
        h = int(h / 2.2)
    return vetor

# %%
def shell_sort2(vetor):
  intervalo = len(vetor) // 2

  while intervalo > 0:
    for i in range(intervalo, len(vetor)):
      temp = vetor[i]
      j = i
      while j >= intervalo and vetor[j - intervalo] > temp:
        vetor[j] = vetor[j - intervalo]
        j -= intervalo
      vetor[j] = temp
    intervalo //= 2

  return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit shell_sort1(vet)

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit shell_sort2(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Quick sort  (  O(n log n)  mas existem casos O(n**2)  )

# %%
def particao(vetor, inicio, final):
    pivo = vetor[final]
    i = inicio - 1

    for j in range(inicio, final):
        if vetor[j] <= pivo:
            i += 1
            vetor[i], vetor[j] = vetor[j], vetor[i]
        vetor[i + 1], vetor[final] = vetor[final], vetor[i + 1]
    return i + 1

def quick_sort(vetor, inicio=0, final=(len(vetor)-1)):
    if inicio < final:
        posicao = particao(vetor, inicio, final)
        # Esquerda
        quick_sort(vetor, inicio, posicao - 1)
        # Direito
        quick_sort(vetor, posicao + 1, final)
    return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit quick_sort(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Merge sort  ( O(n log n) )

# %%
# merge sort
def merge_sort(vetor):
    if len(vetor) > 1:
        divisao = len(vetor) // 2
        esquerda = vetor[:divisao].copy()
        direita = vetor[divisao:].copy()

        merge_sort(esquerda)
        merge_sort(direita)

        i, j, k = 0, 0, 0

        # Ordena esquerda e direita
        while i < len(esquerda) and j < len(direita):
            if esquerda[i] < direita[j]:
                vetor[k] = esquerda[i]
                i += 1
            else:
                vetor[k] = direita[j]
                j += 1
            k += 1

        # Ordenação final
        while i < len(esquerda):
            vetor[k] = esquerda[i]
            i += 1
            k += 1
        while j < len(direita):
            vetor[k] = direita[j]
            j += 1
            k += 1
    return vetor

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
# %timeit merge_sort(vet)

# %%
# Vetor ordenado
print(vet)

# %% [markdown]
# ## Comparativo entre algoritmos

# %%
n = 5000
vet = list(np.random.randint(0,1000,n))

# %%
type(vet)
# Out:
# list

# %%
vet = np.array(vet)
type(vet)
# Out:
# numpy.ndarray

# %%
len(vet)
# Out:
# 5000

# %%
# %timeit bubble_sort(vet.copy())
# Out:
# 2.57 s ± 24.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit selection_sort(vet.copy())
# Out:
# 1.27 s ± 17.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit insertion_sort2(vet.copy())
# Out:
# 1.8 s ± 12.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit shell_sort1(vet.copy())
# Out:
# 1.26 s ± 17.1 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit quick_sort(vet.copy(), 0, len(vetor) - 1)
# Out:
# 26.5 ms ± 486 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit merge_sort(vet.copy())
# Out:
# 18.2 ms ± 553 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ## Fim das Aulas 11 e 12
